# %%
import os

f_path = "D:/bdd100k/images/train/"
file_list = os.listdir(f_path)
s_cmd = "python visualize_flow.py --eval_type seq --seq_dir "

flow_path = "D:/bdd100k/flows/train/"
flow_file_list = os.listdir(flow_path)

for i in file_list:
    if i in flow_file_list:
        print('already DONE!!')
        continue
    r_cmd = s_cmd + f_path + i +'/images/' + ' --name ' + i
    print(r_cmd)
    os.system(r_cmd)
# Out:
# python visualize_flow.py --eval_type seq --seq_dir D:/bdd100k/images/train/02b7b9ee-74fb981c/images/ --name 02b7b9ee-74fb981c
# python visualize_flow.py --eval_type seq --seq_dir D:/bdd100k/images/train/02b7b9ee-7d7a2e00/images/ --name 02b7b9ee-7d7a2e00
# python visualize_flow.py --eval_type seq --seq_dir D:/bdd100k/images/train/02b7b9ee-a2aba88b/images/ --name 02b7b9ee-a2aba88b
# python visualize_flow.py --eval_type seq --seq_dir D:/bdd100k/images/train/02b7b9ee-a76d996e/images/ --name 02b7b9ee-a76d996e
# python visualize_flow.py --eval_type seq --seq_dir D:/bdd100k/images/train/02bb67ae-0a494249/images/ --name 02bb67ae-0a494249
# python visualize_flow.py --eval_type seq --seq_dir D:/bdd100k/images/train/02bb67ae-7627384f/images/ --name 02bb67ae-7627384f
# python visualize_flow.py --eval_type seq --seq_dir D:/bdd100k/images/train/02bb67ae-8c3d61f8/images/ --name 02bb67ae-8c3d61f8
# ...
